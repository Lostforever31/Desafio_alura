# %% [markdown]
# <a href="https://colab.research.google.com/github/Lostforever31/Desafio_alura/blob/main/resolu%C3%A7%C3%A3o_desafio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q -U google-generativeai
# !pip install ipy

# %%
from ipywidgets import IntSlider, Text, Button, Label, HBox, VBox
from IPython.display import display
import google.generativeai as genai
from google.colab import userdata

# Configure o Google Gemini
api_key = userdata.get("SECRET_KEY")
genai.configure(api_key=api_key)

generation_config = {
 "candidate_count": 1,
 "temperature": 0.5,
}

safety_settings = {
 'HATE': 'BLOCK_NONE',
 'HARASSMENT': 'BLOCK_NONE',
 'SEXUAL': 'BLOCK_NONE',
 'DANGEROUS': 'BLOCK_NONE'
}

model = genai.GenerativeModel(
 model_name="gemini-1.0-pro",
 generation_config=generation_config,
 safety_settings=safety_settings
)

chat = model.start_chat(history=[])

# Função para processar os dados
def processar_dados(botao):
    try:
        custo_total = (custo_input.value)
        quanto_gastar = (gastar_input.value)
        tempo_meta = (meta_input.value)
    except ValueError:
        print("Por favor, insira valores numéricos válidos para os custos e tempo.")
        return

    sonho = sonho_text.value

    if sonho:
        prompt = f"Gostaria de {sonho}, que custa no total {custo_total}, mas consigo gastar apenas {quanto_gastar} e pretendo atingir a meta em {tempo_meta} ."
        response = chat.send_message(prompt)
        print("Resposta:", response.text, "\n")
    else:
        print("Por favor, descreva seu sonho.")

# Widgets
custo_label = Label("Custo total e moeda:")
custo_input = Text(placeholder='Digite o valor')

sonho_label = Label("Qual seu objetivo")
sonho_text = Text(placeholder='Digite sua meta que deseja planejar financeiramente')

# Input para "quanto você consegue gastar"
gastar_label = Label("Quanto você consegue gastar em reais ou na moeda desejada:")
gastar_input = Text(placeholder='Digite o valor')

# Input para "quanto tempo pretende atingir a meta"
tempo_label = Label("Em quantos anos/ meses pretende atingir a meta:")
meta_input = Text(placeholder='Digite o tempo ')

# Botão único para enviar
botao_enviar = Button(description='Enviar')
botao_enviar.on_click(processar_dados)

# Organizando a disposição dos elementos com os inputs separados
display(VBox([
  HBox([custo_label, custo_input]),
  HBox([sonho_label, sonho_text]),
  HBox([gastar_label, gastar_input]),
  HBox([tempo_label, meta_input]),
  botao_enviar
]))
# Out:
# ...
# Resposta: **Plano de Poupança para Viagem à Europa**
#
# **Objetivo:** Poupar 100.000 reais para uma viagem à Europa em 2 anos
#
# **Valor atual:** 1.800 reais
#
# **Valor mensal necessário:** 100.000 / 24 (meses) = 4.166,67 reais
#
# **Como atingir a meta:**
#
# **1. Aumentar a renda:**
#
# * Procure oportunidades de ganhar mais dinheiro, como um segundo emprego ou trabalho freelance.
# * Negocie um aumento salarial ou promoção.
#
# **2. Reduzir despesas:**
#
# * Crie um orçamento e identifique áreas onde pode cortar gastos desnecessários.
# * Cozinhe mais refeições em casa, opte por opções de entretenimento gratuitas e negocie contas.
#
# **3. Poupar automaticamente:**
#
# * Configure uma transferência automática da sua conta corrente para uma conta poupança dedicada todos os meses.
# * Participe de um plano de poupança do empregador, se disponível.
#
# **4. Investir:**
#
# ...
